# %%
import requests
from bs4 import BeautifulSoup

# %%
url = ['https://tabelog.com/hyogo/rstLst/izakaya', 'https://tabelog.com/hyogo/rstLst/izakaya/2/','https://tabelog.com/hyogo/rstLst/izakaya/3/',
      'https://tabelog.com/hyogo/rstLst/izakaya/4/','https://tabelog.com/hyogo/rstLst/izakaya/5/','https://tabelog.com/hyogo/rstLst/izakaya/6/',
      'https://tabelog.com/hyogo/rstLst/izakaya/7/', 'https://tabelog.com/hyogo/rstLst/izakaya/8/', 'https://tabelog.com/hyogo/rstLst/izakaya/9/',
      'https://tabelog.com/hyogo/rstLst/izakaya/9/','https://tabelog.com/hyogo/rstLst/izakaya/10/','https://tabelog.com/hyogo/rstLst/izakaya11/',
       'https://tabelog.com/hyogo/rstLst/izakaya/12/','https://tabelog.com/hyogo/rstLst/izakaya/13/','https://tabelog.com/hyogo/rstLst/izakaya/14/',
      'https://tabelog.com/hyogo/rstLst/izakaya/15/', 'https://tabelog.com/hyogo/rstLst/izakaya/16/', 'https://tabelog.com/hyogo/rstLst/izakaya/17/',
      'https://tabelog.com/hyogo/rstLst/izakaya/18/','https://tabelog.com/hyogo/rstLst/izakaya/19/','https://tabelog.com/hyogo/rstLst/izakaya20/'      
      'https://tabelog.com/hyogo/rstLst/izakaya/21/', 'https://tabelog.com/hyogo/rstLst/izakaya/22/','https://tabelog.com/hyogo/rstLst/izakaya/23/',
      'https://tabelog.com/hyogo/rstLst/izakaya/24/','https://tabelog.com/hyogo/rstLst/izakaya/25/','https://tabelog.com/hyogo/rstLst/izakaya/26/',
      'https://tabelog.com/hyogo/rstLst/izakaya/27/', 'https://tabelog.com/hyogo/rstLst/izakaya/28/', 'https://tabelog.com/hyogo/rstLst/izakaya/29/',
      'https://tabelog.com/hyogo/rstLst/izakaya/30/','https://tabelog.com/hyogo/rstLst/izakaya/31/','https://tabelog.com/hyogo/rstLst/izakaya32/',
       'https://tabelog.com/hyogo/rstLst/izakaya/33/','https://tabelog.com/hyogo/rstLst/izakaya/34/','https://tabelog.com/hyogo/rstLst/izakaya/35/',
      'https://tabelog.com/hyogo/rstLst/izakaya/36/', 'https://tabelog.com/hyogo/rstLst/izakaya/37/', 'https://tabelog.com/hyogo/rstLst/izakaya/38/',
      'https://tabelog.com/hyogo/rstLst/izakaya/39/','https://tabelog.com/hyogo/rstLst/izakaya/40/','https://tabelog.com/hyogo/rstLst/izakaya41/'     
      
      ]

restaurant_name =[]
kuchikomi_url = []
for i in url:
    taberogu = requests.get(i)
    soup = BeautifulSoup(taberogu.text, 'html.parser')
    for i in soup.find_all(class_ ='list-rst__rst-name-target cpy-rst-name'):
         print("店名",i.text)
         restaurant_name.append(i.text)  
         url = i.get("href")
         url = url + ("dtlrvwlst/")   
         print(url)
         kuchikomi_url .append(url)
# Out:
# 店名 焔立つ肉寿司と牛タンタワー 肉処 双葉 三宮
# https://tabelog.com/hyogo/A2801/A280101/28057112/dtlrvwlst/
# 店名 神戸焼肉 みつわ屋
# https://tabelog.com/hyogo/A2801/A280101/28056699/dtlrvwlst/
# 店名 地鶏地酒地野菜 絆～ＫＩＺＵＮＡ～
# https://tabelog.com/hyogo/A2801/A280101/28043292/dtlrvwlst/
# 店名 なきぼくろ Dining
# https://tabelog.com/hyogo/A2801/A280101/28002058/dtlrvwlst/
# 店名 炭火焼鳥 鳥料理 IPPO 三宮本店
# https://tabelog.com/hyogo/A2801/A280101/28022823/dtlrvwlst/
# 店名 楽関記
# https://tabelog.com/hyogo/A2801/A280102/28049146/dtlrvwlst/
# 店名 銀しゃりＤｉｎｉｎｇ灯戸
# https://tabelog.com/hyogo/A2801/A280101/28009657/dtlrvwlst/
# 店名 Don CIELO
# https://tabelog.com/hyogo/A2801/A280101/28032257/dtlrvwlst/
# 店名 全席個室 炙り肉寿司×肉バル 楓 三宮店
# https://tabelog.com/hyogo/A2801/A280101/28057051/dtlrvwlst/
# 店名 萬寿殿
# https://tabelog.com/hyogo/A2801/A280101/28000200/dtlrvwlst/
# 店名 熟成魚VS熟成肉 個室 ジパング 三宮
# https://tabelog.com/hyogo/A2801/A280101/28043167/dtlrvwlst/
# 店名 魚貝・鶏料理・日本酒 とよ新
# https://tabelog.com/hyogo/A2801/A280101/28054433/dtlrvwlst/
# 店名 夜景×チーズ肉バル GARDEN 三宮
# ...

# %%
restaurant_name
# Out:
# ['焔立つ肉寿司と牛タンタワー 肉処 双葉 三宮',
#  '神戸焼肉 みつわ屋',
#  '地鶏地酒地野菜 絆～ＫＩＺＵＮＡ～',
#  'なきぼくろ Dining',
#  '炭火焼鳥 鳥料理 IPPO 三宮本店',
#  '楽関記',
#  '銀しゃりＤｉｎｉｎｇ灯戸',
#  'Don CIELO',
#  '全席個室 炙り肉寿司×肉バル 楓 三宮店',
#  '萬寿殿',
#  '熟成魚VS熟成肉 個室 ジパング 三宮',
#  '魚貝・鶏料理・日本酒 とよ新',
#  '夜景×チーズ肉バル GARDEN 三宮',
#  '炙り肉寿司食べ放題 個室居酒屋 一休さん 三宮店',
#  '焼肉 たくちゃん',
#  'お好み焼 鉄板焼 柳家',
#  '焼肉・にくなべ屋 びいどろ 北野坂店',
#  'わさら',
#  '炭火焼肉\u3000ひよりや',
#  '完全個室居酒屋バル 権兵衛 三宮',
#  '黒壱',
#  '海鮮問屋 三宮 セリ壱',
#  '芋の花',
#  '北陸地魚や 一豪一笑',
#  '三宮 天ぷら酒場 上ル商店',
#  'とり禅',
#  'すがはら',
#  '神戸三宮肉寿司',
#  'ロジバル',
#  '手包み餃子酒場 CHANJA 三宮駅前店',
#  'しゃぶしゃぶれたす 神戸三宮店',
#  '肴菜 たくさん',
#  'うし松',
#  'からから屋 三宮店',
#  'さかな料理 たから',
#  'ねぎや',
#  'まいど',
#  '天ぷら海鮮 神福',
#  '銀しゃりdining 火土木',
#  '焼肉どんどん 三ノ宮店',
#  '味彩',
#  'アントン',
#  '備長炭串焼き 大山どり ゆきひら 玉津店',
#  '旨唐揚げと居酒メシ ミライザカ 明石駅前店',
#  '酒菜 咲咲',
#  'シティライツ',
#  'ラクレットチーズ&魚×肉バル トロロッソ',
#  '華和ゐ',
#  'ヨクバリ食堂',
#  '楠くす',
#  '手巻き焼肉 金の牛 三宮本店',
#  '個室 四国郷土活性化 藁家88 神戸駅前店',
#  '鶴蓮',
#  '神戸ステーキ雅',
#  'てこいち十年屋 三宮店',
#  '立ち食い焼肉 牛ごろ',
#  'たまるや北野坂',
# ...

# %%
kuchikomi_url
# Out:
# ['https://tabelog.com/hyogo/A2801/A280101/28057112/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28056699/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28043292/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28002058/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28022823/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280102/28049146/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28009657/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28032257/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28057051/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28000200/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28043167/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28054433/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28052160/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28057113/dtlrvwlst/',
#  'https://tabelog.com/hyogo/A2801/A280101/28056263/dtlrvwlst/',
# ...

# %%
url = 'https://tabelog.com/hyogo/A2801/A280101/28001611/dtlrvwlst/'
 
kuchikomi =requests.get(url)
kuchikomi = BeautifulSoup(kuchikomi.text,'html.parser')
kuchikomi = kuchikomi.find(class_='rstdtl-rvwlst')
kuchikomi = kuchikomi.find(class_='rvw-item__rvw-comment')
for i in kuchikomi.find_all("p"):
    print(i.text)
# Out:
#             全く予備知識が無い中で、こちらをホットペッパーにて見つけました。最終日打ち上げで20名超。近畿らしく鉄板焼ながら破格の飲み放題付2880円は全く期待をしておりませんでしたが、中々です。まずお店...
